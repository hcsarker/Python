# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

# %matplotlib inline 

from urllib.request import urlopen 
from bs4 import BeautifulSoup
import re

# %%
url ="https://www.hubertiming.com/results/2025HVFunRun"

html=urlopen(url)

# %%
soup = BeautifulSoup(html)

# %%
title = soup.title
print(title)  # <title>
print(title.text)
# Out:
# <title>Race results for the 2025 Happy Valley Fun Run!</title>
# Race results for the 2025 Happy Valley Fun Run!

# %%
links = soup.find_all('a', href=True)
for link in links:
        print(link.get('href'))
# Out:
# https://www.hvepto.org/
# mailto:timing@hubertiming.com
# https://www.hubertiming.com
# /results/2025HVFunRun10K
# /results/summary/2025HVFunRun
# #tabs-1
# https://www.hubertiming.com/
# https://facebook.com/hubertiming/

# %%
data = []
allrows = soup.find_all("tr")
for row in allrows:
    row_data = row.find_all("td")
    dataRow = []
    for cell in row_data:
        dataRow.append(cell.text)
    data.append(dataRow)
data = data[4:]  # Skip the header row
print(data[-2:])
# Out:
# [['233', '138', '\r\n\r\n                    ALICE SARIEDDINE\r\n\r\n                ', 'F', '9', 'HAPPY VALLEY', 'OR', '1:02:36', '20:11', '\r\n\r\n                    126 of 126\r\n\r\n                ', 'F 9 and Under', '\r\n\r\n                    5 of 5\r\n\r\n                ', '0:02', '1:02:38'], ['234', '139', '\r\n\r\n                    ROY SARIEDDINE\r\n\r\n                ', 'M', '7', 'HAPPY VALLEY', 'OR', '1:03:08', '20:21', '\r\n\r\n                    108 of 108\r\n\r\n                ', 'M 9 and Under', '\r\n\r\n                    8 of 8\r\n\r\n                ', '0:02', '1:03:10']]

# %%
df = pd.DataFrame(data)
print(df.head(2))
# Out:
#      0     1                                                  2     3     4   \
# 0  None  None                                               None  None  None
# 1     1   251  \r\n\r\n                    GRAYCIN JANZEN\r\n...     M    17
#
#              5     6      7     8   \
# 0          None  None   None  None
# 1  HAPPY VALLEY    OR  20:56  6:45
#
#                                                   9          10  \
# 0                                               None       None
# 1  \r\n\r\n                    1 of 108\r\n\r\n  ...  M Overall
#
#                                                   11    12     13
# 0                                               None  None   None
# 1  \r\n\r\n                    1 of 3\r\n\r\n    ...  0:03  20:59

# %%
header_list = []
col_headers = soup.find_all("th")
for col in col_headers:
    header_list.append(col.text)

print(header_list)
# Out:
# ['Place', 'Bib', 'Name', 'Gender', 'Age', 'City', 'State', 'Time', 'Chip Pace', 'Gender Place', 'Division', 'Division Place', 'Time to Start', 'Gun Time']

# %%
df.columns = header_list
print(df.head())
# Out:
#   Place   Bib                                               Name Gender   Age  \
# 0  None  None                                               None   None  None
# 1     1   251  \r\n\r\n                    GRAYCIN JANZEN\r\n...      M    17
# 2     2    61  \r\n\r\n                    JACK WEIGEL\r\n\r\...      M    13
# 3     3   249  \r\n\r\n                    ROBERT DELGADO\r\n...      M    16
# 4     4   168  \r\n\r\n                    JAYDEN DA SILVA\r\...      M    15
#
#            City State   Time Chip Pace  \
# 0          None  None   None      None
# 1  HAPPY VALLEY    OR  20:56      6:45
# 2      DAMASCUS    OR  21:23      6:53
# 3  HAPPY VALLEY    OR  21:37      6:58
# 4  HAPPY VALLEY    OR  21:49      7:02
#
#                                         Gender Place   Division  \
# 0                                               None       None
# 1  \r\n\r\n                    1 of 108\r\n\r\n  ...  M Overall
# 2  \r\n\r\n                    2 of 108\r\n\r\n  ...  M Overall
# 3  \r\n\r\n                    3 of 108\r\n\r\n  ...  M Overall
# 4  \r\n\r\n                    4 of 108\r\n\r\n  ...    M 15-19
#
#                                       Division Place Time to Start Gun Time
# 0                                               None          None     None
# 1  \r\n\r\n                    1 of 3\r\n\r\n    ...          0:03    20:59
# 2  \r\n\r\n                    2 of 3\r\n\r\n    ...          0:06    21:29
# 3  \r\n\r\n                    3 of 3\r\n\r\n    ...          0:04    21:41
# 4  \r\n\r\n                    1 of 13\r\n\r\n   ...          0:02    21:51

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Place           234 non-null    object
#  1   Bib             234 non-null    object
#  2   Name            234 non-null    object
#  3   Gender          234 non-null    object
#  4   Age             234 non-null    object
#  5   City            234 non-null    object
#  6   State           234 non-null    object
#  7   Time            234 non-null    object
#  8   Chip Pace       234 non-null    object
#  9   Gender Place    234 non-null    object
#  10  Division        234 non-null    object
#  11  Division Place  234 non-null    object
#  12  Time to Start   234 non-null    object
#  13  Gun Time        234 non-null    object
# dtypes: object(14)
# memory usage: 25.8+ KB

# %%
df.describe(include='all')
# Out:
#        Place  Bib                                               Name Gender  \
# count    234  234                                                234    234
# unique   234  234                                                234      2
# top        1  251  \r\n\r\n                    GRAYCIN JANZEN\r\n...      F
# freq       1    1                                                  1    126
#
#         Age          City State   Time Chip Pace  \
# count   234           234   234    234       234
# unique   62            31     9    213       185
# top      11  HAPPY VALLEY    OR  24:32     11:09
# freq     13           128   218      2         4
#
#                                              Gender Place Division  \
# count                                                 234      234
# unique                                                234       30
# top     \r\n\r\n                    1 of 108\r\n\r\n  ...  F 10-14
# freq                                                    1       17
#
#                                            Division Place Time to Start  \
# count                                                 234           234
# unique                                                120            67
# top     \r\n\r\n                    1 of 7\r\n\r\n    ...          0:04
# freq                                                    4            13
#
#        Gun Time
# count       234
# unique      212
# top       32:57
# freq          3

# %%
df.shape
# Out:
# (235, 14)

# %%
df2 = df.dropna(how ='any')
df2.shape
# Out:
# (234, 14)

# %%
df
# Out:
#     Place   Bib                                               Name Gender  \
# 0    None  None                                               None   None
# 1       1   251  \r\n\r\n                    GRAYCIN JANZEN\r\n...      M
# 2       2    61  \r\n\r\n                    JACK WEIGEL\r\n\r\...      M
# 3       3   249  \r\n\r\n                    ROBERT DELGADO\r\n...      M
# 4       4   168  \r\n\r\n                    JAYDEN DA SILVA\r\...      M
# ..    ...   ...                                                ...    ...
# 230   230    57  \r\n\r\n                    JESSICA YANG\r\n\r...      F
# 231   231    18  \r\n\r\n                    ROSELYN SHAMMASIAN...      F
# 232   232    19  \r\n\r\n                    NOVA WEISEL\r\n\r\...      F
# 233   233   138  \r\n\r\n                    ALICE SARIEDDINE\r...      F
# 234   234   139  \r\n\r\n                    ROY SARIEDDINE\r\n...      M
#
#       Age          City State     Time Chip Pace  \
# 0    None          None  None     None      None
# 1      17  HAPPY VALLEY    OR    20:56      6:45
# 2      13      DAMASCUS    OR    21:23      6:53
# 3      16  HAPPY VALLEY    OR    21:37      6:58
# 4      15  HAPPY VALLEY    OR    21:49      7:02
# ..    ...           ...   ...      ...       ...
# 230    24  HAPPY VALLEY    OR  1:02:03     20:00
# 231    40  HAPPY VALLEY    OR  1:02:33     20:10
# 232     9  HAPPY VALLEY    OR  1:02:33     20:10
# 233     9  HAPPY VALLEY    OR  1:02:36     20:11
# 234     7  HAPPY VALLEY    OR  1:03:08     20:21
#
#                                           Gender Place       Division  \
# 0                                                 None           None
# 1    \r\n\r\n                    1 of 108\r\n\r\n  ...      M Overall
# 2    \r\n\r\n                    2 of 108\r\n\r\n  ...      M Overall
# 3    \r\n\r\n                    3 of 108\r\n\r\n  ...      M Overall
# 4    \r\n\r\n                    4 of 108\r\n\r\n  ...        M 15-19
# ..                                                 ...            ...
# 230  \r\n\r\n                    123 of 126\r\n\r\n...        F 20-24
# 231  \r\n\r\n                    124 of 126\r\n\r\n...        F 40-44
# 232  \r\n\r\n                    125 of 126\r\n\r\n...  F 9 and Under
# 233  \r\n\r\n                    126 of 126\r\n\r\n...  F 9 and Under
# 234  \r\n\r\n                    108 of 108\r\n\r\n...  M 9 and Under
#
#                                         Division Place Time to Start Gun Time
# 0                                                 None          None     None
# 1    \r\n\r\n                    1 of 3\r\n\r\n    ...          0:03    20:59
# 2    \r\n\r\n                    2 of 3\r\n\r\n    ...          0:06    21:29
# 3    \r\n\r\n                    3 of 3\r\n\r\n    ...          0:04    21:41
# 4    \r\n\r\n                    1 of 13\r\n\r\n   ...          0:02    21:51
# ..                                                 ...           ...      ...
# 230  \r\n\r\n                    10 of 10\r\n\r\n  ...          0:00  1:02:03
# 231  \r\n\r\n                    14 of 14\r\n\r\n  ...          0:40  1:03:13
# 232  \r\n\r\n                    4 of 5\r\n\r\n    ...          0:40  1:03:13
# 233  \r\n\r\n                    5 of 5\r\n\r\n    ...          0:02  1:02:38
# 234  \r\n\r\n                    8 of 8\r\n\r\n    ...          0:02  1:03:10
#
# [235 rows x 14 columns]

# %%
df2
# Out:
#     Place  Bib                                               Name Gender Age  \
# 1       1  251  \r\n\r\n                    GRAYCIN JANZEN\r\n...      M  17
# 2       2   61  \r\n\r\n                    JACK WEIGEL\r\n\r\...      M  13
# 3       3  249  \r\n\r\n                    ROBERT DELGADO\r\n...      M  16
# 4       4  168  \r\n\r\n                    JAYDEN DA SILVA\r\...      M  15
# 5       5  116  \r\n\r\n                    JAMES JONES\r\n\r\...      M  16
# ..    ...  ...                                                ...    ...  ..
# 230   230   57  \r\n\r\n                    JESSICA YANG\r\n\r...      F  24
# 231   231   18  \r\n\r\n                    ROSELYN SHAMMASIAN...      F  40
# 232   232   19  \r\n\r\n                    NOVA WEISEL\r\n\r\...      F   9
# 233   233  138  \r\n\r\n                    ALICE SARIEDDINE\r...      F   9
# 234   234  139  \r\n\r\n                    ROY SARIEDDINE\r\n...      M   7
#
#              City State     Time Chip Pace  \
# 1    HAPPY VALLEY    OR    20:56      6:45
# 2        DAMASCUS    OR    21:23      6:53
# 3    HAPPY VALLEY    OR    21:37      6:58
# 4    HAPPY VALLEY    OR    21:49      7:02
# 5    HAPPY VALLEY    OR    21:53      7:03
# ..            ...   ...      ...       ...
# 230  HAPPY VALLEY    OR  1:02:03     20:00
# 231  HAPPY VALLEY    OR  1:02:33     20:10
# 232  HAPPY VALLEY    OR  1:02:33     20:10
# 233  HAPPY VALLEY    OR  1:02:36     20:11
# 234  HAPPY VALLEY    OR  1:03:08     20:21
#
#                                           Gender Place       Division  \
# 1    \r\n\r\n                    1 of 108\r\n\r\n  ...      M Overall
# 2    \r\n\r\n                    2 of 108\r\n\r\n  ...      M Overall
# 3    \r\n\r\n                    3 of 108\r\n\r\n  ...      M Overall
# 4    \r\n\r\n                    4 of 108\r\n\r\n  ...        M 15-19
# 5    \r\n\r\n                    5 of 108\r\n\r\n  ...        M 15-19
# ..                                                 ...            ...
# 230  \r\n\r\n                    123 of 126\r\n\r\n...        F 20-24
# 231  \r\n\r\n                    124 of 126\r\n\r\n...        F 40-44
# 232  \r\n\r\n                    125 of 126\r\n\r\n...  F 9 and Under
# 233  \r\n\r\n                    126 of 126\r\n\r\n...  F 9 and Under
# 234  \r\n\r\n                    108 of 108\r\n\r\n...  M 9 and Under
#
#                                         Division Place Time to Start Gun Time
# 1    \r\n\r\n                    1 of 3\r\n\r\n    ...          0:03    20:59
# 2    \r\n\r\n                    2 of 3\r\n\r\n    ...          0:06    21:29
# 3    \r\n\r\n                    3 of 3\r\n\r\n    ...          0:04    21:41
# 4    \r\n\r\n                    1 of 13\r\n\r\n   ...          0:02    21:51
# 5    \r\n\r\n                    2 of 13\r\n\r\n   ...          0:00    21:53
# ..                                                 ...           ...      ...
# 230  \r\n\r\n                    10 of 10\r\n\r\n  ...          0:00  1:02:03
# 231  \r\n\r\n                    14 of 14\r\n\r\n  ...          0:40  1:03:13
# 232  \r\n\r\n                    4 of 5\r\n\r\n    ...          0:40  1:03:13
# 233  \r\n\r\n                    5 of 5\r\n\r\n    ...          0:02  1:02:38
# 234  \r\n\r\n                    8 of 8\r\n\r\n    ...          0:02  1:03:10
#
# [234 rows x 14 columns]

# %%
df2['Age'] = df2['Age'].astype(int)
df2['Age'].describe()
# Out:
# /tmp/ipykernel_20058/1491625070.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Age'] = df2['Age'].astype(int)
# count    234.000000
# mean      33.662393
# std       17.451383
# min        6.000000
# 25%       17.000000
# 50%       33.000000
# 75%       46.000000
# max       79.000000
# Name: Age, dtype: float64

# %%
# Convert 'Time' to timedelta, invalid formats become NaT
df2['chiptime'] = pd.to_timedelta(df2['Time'], errors='coerce')
df2[['chiptime']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234 entries, 1 to 234
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   chiptime  6 non-null      timedelta64[ns]
# dtypes: timedelta64[ns](1)
# memory usage: 3.7 KB
# /tmp/ipykernel_20058/2616813608.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['chiptime'] = pd.to_timedelta(df2['Time'], errors='coerce')
